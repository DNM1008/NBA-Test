# %%
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score, auc, classification_report, roc_auc_score, roc_curve
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
import matplotlib.pyplot as plt
import numpy as np
import pickle
import pprint
import pandas as pd
import xgboost as xgb

# %%
# Labelling function
def labelling(df, col, num_bins):
    """
    Apply quantile-based binning to a column in the DataFrame.
    """
    df[col] = pd.qcut(df[col], q=num_bins, labels=False, duplicates='drop')
    return df

# Binning function for age groups
def bin_age_groups(train_df, test_df):
    """
    Bin the 'Age_y' column into defined age groups.
    """
    age_bin_edges = [0, 20, 25, 30, 35, 40, 45, 50, 55, 60, float('inf')]
    labels = ['Duoi 20', '20 toi 24', '25 toi 29', '30 toi 34', '35 toi 39', 
              '40 toi 44', '45 toi 49', '50 toi 54', '55 toi 59', 'Tren 60']

    train_df['Age_group'] = pd.cut(train_df['Age_y'], bins=age_bin_edges, labels=labels, right=False)
    test_df['Age_group'] = pd.cut(test_df['Age_y'], bins=age_bin_edges, labels=labels, right=False)
    return train_df, test_df

def preprocess_data(train_path, test_path):
    """
    Preprocess train and test datasets by aligning numeric columns, 
    binning age groups, and dropping unnecessary columns.
    """
    train = pd.read_csv(train_path)
    test = pd.read_parquet(test_path)

    # Drop specified columns
    cols_to_drop = ['Age_x', 'CIF_CLSCUS', 'COB_DATE', 'DATE_TIME', 
                    'BRN_OPN_CIF', 'MA_PHONG_GIAO_DICH_VCB', 
                    'CIF_MASK', 'IS_TM', 'Unnamed: 0', 
                    'SUM_CBALQ_LH_6m', 'SUM_CBALQ_LH_3m', 'AVG_GR_SUM_CBALQ_LH']
    train = train.drop(columns=[col for col in cols_to_drop if col in train.columns], errors='ignore')
    test = test.drop(columns=[col for col in cols_to_drop if col in test.columns], errors='ignore')

    # Bin age groups
    train, test = bin_age_groups(train, test)

    # Align numeric columns
    numeric_cols = train.select_dtypes(include=[np.number]).columns.intersection(
        test.select_dtypes(include=[np.number]).columns
    )
    train = train[numeric_cols]
    test = test[numeric_cols]

    print(f"Numeric columns aligned: {numeric_cols.tolist()}")
    return train, test



# Model functions (same as previous)
def save_model(train, model_path):
    """
    Save the trained model (normalized data and parameters) to a pickle file.
    """
    # Select only numeric columns
    numeric_cols = train.select_dtypes(include=[np.number]).columns
    X_train = train[numeric_cols].drop(columns=["IS_BANCAS"], errors='ignore').to_numpy()
    y_train = train["IS_BANCAS"].to_numpy()

    # Calculate mean and standard deviation
    mean = X_train.mean(axis=0)
    std = X_train.std(axis=0)

    # Normalize X_train
    X_train_normalized = (X_train - mean) / (std +1e-8)

    # Save the model
    model = {
        "X_train": X_train_normalized,
        "y_train": y_train,
        "mean": mean,
        "std": std
    }
    with open(model_path, "wb") as f:
        pickle.dump(model, f)
    print(f"Model saved to {model_path}")

def predict_new_observation(new_observation, model_path, top_k=20):
    """
    Load the model and predict the expected IS_BANCAS value for a new observation.
    """
    with open(model_path, "rb") as f:
        model = pickle.load(f)

    X_train = model["X_train"]
    y_train = model["y_train"]
    mean = model["mean"]
    std = model["std"]

    new_observation = (new_observation - mean) / std
    similarity = np.dot(X_train, new_observation)
    top_k_indices = np.argsort(-similarity)[:top_k]
    top_k_bancas = y_train[top_k_indices]
    predicted_bancas = round(top_k_bancas.mean())
    return predicted_bancas

def predict_first_n_observations(test, model_path, n=10, top_k=20):
    """
    Predict the "IS_BANCAS" value for the first N observations in the test dataset
    and print the actual and predicted values.
    """
    with open(model_path, "rb") as f:
        model = pickle.load(f)

    X_train = model["X_train"]
    y_train = model["y_train"]
    mean = model["mean"]
    std = model["std"]

    # Get the first N observations and their actual IS_BANCAS values
    X_test = test.drop(columns=["IS_BANCAS"]).iloc[:n].to_numpy()
    actual_values = test["IS_BANCAS"].iloc[:n].to_numpy()

    print(f"X_train shape: {X_train.shape}")
    print(f"mean shape: {mean.shape}")
    print(f"std shape: {std.shape}")
    print(f"X_test shape: {X_test.shape}")

    # Normalize test data
    X_test = (X_test - mean) / (std + 1e-8)

    predictions = []
    for i in range(X_test.shape[0]):
        # Calculate similarity and predict IS_BANCAS
        similarity = np.dot(X_train, X_test[i])
        top_k_indices = np.argsort(-similarity)[:top_k]
        top_k_bancas = y_train[top_k_indices]
        predicted_bancas = top_k_bancas.mean()
        predictions.append(predicted_bancas)

        # Print the expected and actual values
        print(f"Observation {i + 1}: Predicted IS_BANCAS = {predicted_bancas}, Actual IS_BANCAS = {actual_values[i]}")

    return predictions
    
def predict_all_observations(test, model_path, top_k=20, print_n=10):
    """
    Predict the "IS_BANCAS" value for all observations in the test dataset
    and add the predictions as a new column. Print out predictions for the first `print_n` rows.
    """
    with open(model_path, "rb") as f:
        model = pickle.load(f)

    X_train = model["X_train"]
    y_train = model["y_train"]
    mean = model["mean"]
    std = model["std"]

    # Get all observations from the test set (excluding IS_BANCAS column)
    X_test = test.drop(columns=["IS_BANCAS"]).to_numpy()

    # Normalize test data
    X_test = (X_test - mean) / (std + 1e-8)

    predictions = []
    for i in range(X_test.shape[0]):
        # Calculate similarity and predict IS_BANCAS
        similarity = np.dot(X_train, X_test[i])
        top_k_indices = np.argsort(-similarity)[:top_k]
        top_k_bancas = y_train[top_k_indices]
        predicted_bancas = top_k_bancas.modeinter()
        predictions.append(predicted_bancas)

    # Add the predictions to the test DataFrame
    test["predicted_IS_BANCAS"] = predictions

    # Optionally, print out the first few predictions for inspection
    print(f"Showing the first {min(print_n, len(test))} predictions:")
    print(test[['IS_BANCAS', 'predicted_IS_BANCAS']].head(print_n))

    return test


# File paths
train_path = "data.csv"
test_path = "data-val.parquet"
model_path = "results/collaborative_search_dot_product_model.pkl"

# Step 1: Preprocess data
print("Preprocessing data...")
train, test = preprocess_data(train_path, test_path)

# Step 2: Train and save the model
print("Training and saving the model...")
save_model(train, model_path)
# Out:
# Preprocessing data...
# Numeric columns aligned: ['CBALQ_3m', 'AVG_SL_SP_BOSUNG', 'NO_TREN_CO_6m', 'SUM_CBALQ_LH', 'BHNT_flag', 'MEDIAN_GR_SUM_AMT', 'BHNT_after21', 'Sum_PPC', 'MEDIAN_GR_THGCO', 'BHSK_remain', 'IS_BANCAS', 'AVG_GR_CBALQ', 'CBALQ_6m', 'AVG_CBALQ_6m', 'BHNT_remain', 'AVG_GR_THGCO', 'IS_TM.1', 'Age_y', 'THGCO_3m', 'CNT_TGCCKH', 'THGNO_6m', 'IS_TA', 'TONGTHUNHAPHANGTHANG', 'Snapshot', 'BHSK_flag', 'THGCO_6m', 'MEDIAN_GR_CBALQ', 'AVG_CBALQ_TGCCKH', 'THGNO_3m', 'AVG_AMT_3M', 'NO_TREN_CO_3m', 'AVG_CBALQ_3m', 'BHSK_after21', 'Payroll_Flag', 'AVG_GR_THGNO', 'MEDIAN_GR_THGNO']
# Training and saving the model...
# /home/zeus/.local/lib/python3.12/site-packages/numpy/_core/_methods.py:194: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# /tmp/ipykernel_39590/899116792.py:68: RuntimeWarning: invalid value encountered in subtract
#   X_train_normalized = (X_train - mean) / (std +1e-8)
# Model saved to results/collaborative_search_dot_product_model.pkl

# %%
# Step 3: Predict all observations in the test dataset and show the first 10 predictions
print("Predicting all observations in the test dataset...")
# predicted_test_data = predict_all_observations(test, model_path, top_k=20, print_n=10)
predict_first_n_observations(test, model_path, n=10, top_k=20)
# Out:
# Predicting all observations in the test dataset...
# X_train shape: (1088451, 35)
# mean shape: (35,)
# std shape: (35,)
# X_test shape: (1000, 35)
# /tmp/ipykernel_39590/899116792.py:123: RuntimeWarning: invalid value encountered in subtract
#   X_test = (X_test - mean) / (std + 1e-8)
# Observation 1: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 2: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 3: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 4: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 5: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 6: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 7: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 8: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 9: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 10: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 11: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 12: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 13: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 14: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 15: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 16: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 17: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 18: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 19: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 20: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 21: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 22: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 23: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 24: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 25: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 26: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 27: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 28: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 29: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 30: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 31: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 32: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 33: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 34: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 35: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 36: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 37: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 38: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 39: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 40: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 41: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 42: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 43: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 44: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 45: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 46: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 47: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 48: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 49: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 50: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 51: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 52: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 53: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 54: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 55: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 56: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 57: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 58: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 59: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 60: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 61: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 62: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 63: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 64: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 65: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 66: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 67: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 68: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 69: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 70: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 71: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 72: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 73: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 74: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 75: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 76: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 77: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 78: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 79: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 80: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 81: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 82: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 83: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 84: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 85: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 86: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 87: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 88: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 89: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 90: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 91: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 92: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 93: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 94: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 95: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 96: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 97: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 98: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 99: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 100: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 101: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 102: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 103: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 104: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 105: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 106: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 107: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 108: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 109: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 110: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 111: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 112: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 113: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 114: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 115: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 116: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 117: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 118: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 119: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 120: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 121: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 122: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 123: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 124: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 125: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 126: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 127: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 128: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 129: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 130: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 131: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 132: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 133: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 134: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 135: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 136: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 137: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 138: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 139: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 140: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 141: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 142: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 143: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 144: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 145: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 146: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 147: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 148: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 149: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 150: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 151: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 152: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 153: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 154: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 155: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 156: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 157: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 158: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 159: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 160: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 161: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 162: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 163: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 164: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 165: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 166: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 167: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 168: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 169: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 170: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 171: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 172: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 173: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 174: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 175: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 176: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 177: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 178: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 179: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 180: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 181: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 182: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 183: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 184: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 185: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 186: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 187: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 188: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 189: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 190: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 191: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 192: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 193: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 194: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 195: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 196: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 197: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 198: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 199: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 200: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 201: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 202: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 203: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 204: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 205: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 206: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 207: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 208: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 209: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 210: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 211: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 212: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 213: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 214: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 215: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 216: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 217: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 218: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 219: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 220: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 221: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 222: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 223: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 224: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 225: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 226: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 227: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 228: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 229: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 230: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 231: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 232: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 233: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 234: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 235: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 236: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 237: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 238: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 239: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 240: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 241: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 242: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 243: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 244: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 245: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 246: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 247: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 248: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 249: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 250: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 251: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 252: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 253: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 254: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 255: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 256: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 257: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 258: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 259: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 260: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 261: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 262: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 263: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 264: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 265: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 266: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 267: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 268: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 269: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 270: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 271: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 272: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 273: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 274: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 275: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 276: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 277: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 278: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 279: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 280: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 281: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 282: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 283: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 284: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 285: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 286: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 287: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 288: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 289: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 290: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 291: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 292: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 293: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 294: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 295: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 296: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 297: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 298: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 299: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 300: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 301: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 302: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 303: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 304: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 305: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 306: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 307: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 308: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 309: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 310: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 311: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 312: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 313: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 314: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 315: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 316: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 317: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 318: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 319: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 320: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 321: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 322: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 323: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 324: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 325: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 326: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 327: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 328: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 329: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 330: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# Observation 331: Predicted IS_BANCAS = 1, Actual IS_BANCAS = 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 4
#       2 print("Predicting all observations in the test dataset...")
#       3 # predicted_test_data = predict_all_observations(test, model_path, top_k=20, print_n=10)
# ----> 4 predict_first_n_observations(test, model_path, n=1000, top_k=20)
#
# Cell In[5], line 128, in predict_first_n_observations(test, model_path, n, top_k)
#     125 predictions = []
#     126 for i in range(X_test.shape[0]):
#     127     # Calculate similarity and predict IS_BANCAS
# --> 128     similarity = np.dot(X_train, X_test[i])
#     129     top_k_indices = np.argsort(-similarity)[:top_k]
#     130     top_k_bancas = y_train[top_k_indices]
#
# KeyboardInterrupt:
